# %%
import numpy as np
import pandas as pd

raw = pd.read_csv('topics_index.tsv', '\t')[:-1]

# last row is NA, which also turns our numerics into floats. coerce back.
raw.id = raw.id.astype(int)
raw.page_count = raw.page_count.astype(int)

raw.columns
# Out:
# Index(['id', 'op', 'page_count', 'category', 'title', 'url'], dtype='object')

# %%
# df.loc[df['op'] == 'eSCSi']
raw.groupby(['op'], sort=False).get_group('eSCSi') # fast
# Out:
#           id     op  page_count           category  \
# 22971  41538  eSCSi         365     Spore Roleplay
# 22972  45708  eSCSi         173     Spore Roleplay
# 22973  57096  eSCSi          69     Spore Roleplay
# 22974  56446  eSCSi          21     Spore Roleplay
# 22975  49553  eSCSi          19     Spore Roleplay
# 22976  45652  eSCSi          15     Spore Roleplay
# 22977  52134  eSCSi          10     Spore Roleplay
# 22978  64863  eSCSi          10     Spore Roleplay
# 22979  78116  eSCSi          10     Spore Roleplay
# 22980  55544  eSCSi           9     Spore Roleplay
# 22981  52386  eSCSi           7     Spore Roleplay
# 22982  47166  eSCSi           6     Spore Roleplay
# 22983  45328  eSCSi           4     Spore Roleplay
# 22984  68928  eSCSi           3  Science and Spore
# 22985  46926  eSCSi           2  Science and Spore
# 22986  52686  eSCSi           2     Spore Roleplay
# 22987  53024  eSCSi           2     Spore Roleplay
# 22988  41427  eSCSi           1     Spore Feedback
# 22989  45383  eSCSi           1  Science and Spore
# 22990  47032  eSCSi           1  Science and Spore
# 22991  48660  eSCSi           1     Spore Feedback
# 22992  49839  eSCSi           1  Science and Spore
# 22993  52783  eSCSi           1     Spore Roleplay
# 22994  53762  eSCSi           1     Spore Roleplay
# 22995  65289  eSCSi           1  Science and Spore
#
#                                           title  \
# 22971                Phylum - An Evolution Game
# 22972                   Ancestry (aka Phylum 2)
# 22973          Antimony (Planning Sequel/Reset)
# 22974                          (Evolution Game)
# 22975  Pangenesis - The *Other* Origins of Life
# 22976          Phylum 2 (glitched, do not post)
# 22977                        Planning: A Galaxy
# 22978                  Impiety - Half An Update
# 22979               Alchemy: A Voting RP (Dead)
# 22980                     Planning - Two Forums
# 22981                                  (closed)
# 22982              Old spammy discussion thread
# 22983               Phylum - The Soluplexi Wars
# 22984                         Questions on Mind
# 22985                     Alternative Universes
# 22986               Evolution Games: Discussion
# 22987                         (closed to posts)
# 22988            (Very) Extended Creature Stage
# 22989                                  Xenology
# 22990       People exist to make black holes...
# 22991                         Alternative Spore
# 22992                                      fail
# 22993               Sporesville - failed thread
# 22994                                        ok
# 22995                              Megaprojects
#
#                                                      url
# 22971  http://forum.spore.com/jforum/posts/list/41538...
# 22972  http://forum.spore.com/jforum/posts/list/45708...
# 22973  http://forum.spore.com/jforum/posts/list/57096...
# 22974  http://forum.spore.com/jforum/posts/list/56446...
# 22975  http://forum.spore.com/jforum/posts/list/49553...
# 22976  http://forum.spore.com/jforum/posts/list/45652...
# 22977  http://forum.spore.com/jforum/posts/list/52134...
# 22978  http://forum.spore.com/jforum/posts/list/64863...
# 22979  http://forum.spore.com/jforum/posts/list/78116...
# 22980  http://forum.spore.com/jforum/posts/list/55544...
# 22981  http://forum.spore.com/jforum/posts/list/52386...
# 22982  http://forum.spore.com/jforum/posts/list/47166...
# 22983  http://forum.spore.com/jforum/posts/list/45328...
# 22984  http://forum.spore.com/jforum/posts/list/68928...
# 22985  http://forum.spore.com/jforum/posts/list/46926...
# 22986  http://forum.spore.com/jforum/posts/list/52686...
# 22987  http://forum.spore.com/jforum/posts/list/53024...
# 22988  http://forum.spore.com/jforum/posts/list/41427...
# 22989  http://forum.spore.com/jforum/posts/list/45383...
# 22990  http://forum.spore.com/jforum/posts/list/47032...
# 22991  http://forum.spore.com/jforum/posts/list/48660...
# 22992  http://forum.spore.com/jforum/posts/list/49839...
# 22993  http://forum.spore.com/jforum/posts/list/52783...
# 22994  http://forum.spore.com/jforum/posts/list/53762...
# 22995  http://forum.spore.com/jforum/posts/list/65289...

# %%
# restrict to 'notable ops'
df = raw.groupby(['op'], sort=False).filter(
    lambda x: (x['page_count'] >= 40).any()) # slow

# %%
df.shape, raw.shape
# Out:
# ((12621, 6), (79460, 6))

# %%
# intersect boolean masks - https://stackoverflow.com/a/38884502
byWeight = [
    df[df['page_count'] >= 1000],
    df[(df['page_count'] < 1000) & (df['page_count'] >= 400)],
    df[(df['page_count'] < 400) & (df['page_count'] >= 200)],
    df[(df['page_count'] < 200) & (df['page_count'] >= 100)], # got
    df[(df['page_count'] < 100) & (df['page_count'] >= 50)], # got
    df[(df['page_count'] < 50) & (df['page_count'] >= 20)], # got
    df[(df['page_count'] < 20) & (df['page_count'] >= 5)], # got
    df[df['page_count'] < 5]
]
print( [d.page_count.sum() for d in byWeight] )
print()
print( [d.shape[0] for d in byWeight] )
# Out:
# [31012, 24424, 20700, 26804, 22678, 21347, 19241, 15234]
#
# [18, 42, 79, 193, 329, 661, 2164, 9135]

# %%
# TODO - topics from the sheet splice don't have their URLs preprocessed

','.join(byWeight[2].id.astype(str))
